# %%
import time
 
def task():
    print('Sleeping for 0.5 seconds')
    time.sleep(0.5)
    print('Finished sleeping')

# %%
import multiprocessing
p1 = multiprocessing.Process(target=task)
p2 = multiprocessing.Process(target=task)

# %%
...
p1.start()
p2.start()

# %%
if __name__ == "__main__":
    start_time = time.perf_counter()
 
    # Creates two processes
    p1 = multiprocessing.Process(target=task)
    p2 = multiprocessing.Process(target=task)
 
    # Starts both processes
    p1.start()
    p2.start()
 
    finish_time = time.perf_counter()
 
    print(f"Program finished in {finish_time-start_time} seconds")
# Out:
# Program finished in 0.008879699999999602 seconds

# %%
if __name__ == "__main__": 
    start_time = time.perf_counter()
    processes = []
 
    # Creates 10 processes then starts them
    for i in range(10):
        p = multiprocessing.Process(target = task)
        p.start()
        processes.append(p)
    
    # Joins all the processes 
    for p in processes:
        p.join()
 
    finish_time = time.perf_counter()
 
    print(f"Program finished in {finish_time-start_time} seconds")
# Out:
# Program finished in 0.24389150000000015 seconds

# %%
def cube(x):
    return x**3

# %%
if __name__ == "__main__":
    # this does not work
    processes = [multiprocessing.Process(target=cube, args=(x,)) for x in range(1,1000)]
    [p.start() for p in processes]
    result = [p.join() for p in processes]
    print(result)
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, N
# ...

# %% [raw]
# if __name__ == "__main__":
#     pool = multiprocessing.Pool(3)
#     start_time = time.perf_counter()
#     processes = [pool.apply_async(cube, args=(x,)) for x in range(1,10)]
#     result = [p.get() for p in processes]
#     finish_time = time.perf_counter()
#     print(f"Program finished in {finish_time-start_time} seconds")
#     print(result)

# %% [raw]
# import multiprocessing
# import time
#
# def cube(x):
#     return x**3
#
# if __name__ == "__main__":
#     pool = multiprocessing.Pool(3)
#     start_time = time.perf_counter()
#     result = pool.map(cube, range(1,1000))
#     finish_time = time.perf_counter()
#     print(f"Program finished in {finish_time-start_time} seconds")
#     print(result)

# %%
import concurrent.futures
import time

def cube(x):
    return x**3

def main():
    with concurrent.futures.ProcessPoolExecutor(3) as executor:
        start_time = time.perf_counter()
        result = list(executor.map(cube, range(1,1000)))
        finish_time = time.perf_counter()
    print(f"Program finished in {finish_time-start_time} seconds")
    print(result)

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# BrokenProcessPool                         Traceback (most recent call last)
# Input In [8], in <cell line: 15>()
#      13     print(result)
#      15 if __name__ == '__main__':
# ---> 16     main()
#
# Input In [8], in main()
#       8 with concurrent.futures.ProcessPoolExecutor(3) as executor:
#       9     start_time = time.perf_counter()
# ---> 10     result = list(executor.map(cube, range(1,1000)))
#      11     finish_time = time.perf_counter()
#      12 print(f"Program finished in {finish_time-start_time} seconds")
#
# File ~\AppData\Local\Programs\Python\Python39\lib\concurrent\futures\process.py:559, in _chain_from_iterable_of_lists(iterable)
#     553 def _chain_from_iterable_of_lists(iterable):
#     554     """
#     555     Specialized implementation of itertools.chain.from_iterable.
#     556     Each item in *iterable* should be a list.  This function is
# ...

# %%
pip install joblib

# %%
import time
from joblib import Parallel, delayed
 
def cube(x):
    return x**3
 
start_time = time.perf_counter()
result = Parallel(n_jobs=3)(delayed(cube)(i) for i in range(1,1000))
finish_time = time.perf_counter()
print(f"Program finished in {finish_time-start_time} seconds")
print(result)
# Out:
# Program finished in 0.4438616000000053 seconds
# ...

# %%
import time
from joblib import Parallel, delayed
 
def cube(x):
    return x**3
 
start_time = time.perf_counter()
result = Parallel(n_jobs=-1)(delayed(cube)(i) for i in range(1,1000))
finish_time = time.perf_counter()
print(f"Program finished in {finish_time-start_time} seconds")
print(result)
# Out:
# Program finished in 0.1202298999999698 seconds
# ...

# %%
import time
from joblib import Parallel, delayed
 
def cube(x):
    return x**3
 
start_time = time.perf_counter()
result = Parallel(n_jobs=-1)(delayed(cube)(i) for i in range(1,1000))
#result = Parallel(n_jobs=3)((cube, (i,), {}) for i in range(1,1000))
#result = Parallel(n_jobs=3, prefer="threads")(delayed(cube)(i) for i in range(1,1000))
finish_time = time.perf_counter()
print(f"Program finished in {finish_time-start_time} seconds")
#print(result)
# Out:
# Program finished in 1.109005400000001 seconds

# %%
import time
from joblib import Parallel, delayed
 
def cube(x):
    return x**3
 
start_time = time.perf_counter()
#result = Parallel(n_jobs=-1)(delayed(cube)(i) for i in range(1,1000))
result = Parallel(n_jobs=-1)((cube, (i,), {}) for i in range(1,1000))
#result = Parallel(n_jobs=-1, prefer="threads")(delayed(cube)(i) for i in range(1,1000))
finish_time = time.perf_counter()
print(f"Program finished in {finish_time-start_time} seconds")
#print(result)
# Out:
# Program finished in 0.10347319999993942 seconds

# %%
import time
from joblib import Parallel, delayed
 
def cube(x):
    return x**3
 
start_time = time.perf_counter()
#result = Parallel(n_jobs=-1)(delayed(cube)(i) for i in range(1,1000))
#result = Parallel(n_jobs=-1)((cube, (i,), {}) for i in range(1,1000))
result = Parallel(n_jobs=-1, prefer="threads")(delayed(cube)(i) for i in range(1,1000))
finish_time = time.perf_counter()
print(f"Program finished in {finish_time-start_time} seconds")
#print(result)
# Out:
# Program finished in 0.06175139999993462 seconds
